# %%
#-*- coding: euc-kr -*-
import csv
import pandas as pd
from pandas import Series, DataFrame

""" mission:
 1. 연관 검색어 추천
  - "휴롬" 이라고 검색한 사람에게 "휴롬 2세대" 나, "녹즙기" 이런 관련 검색어를 추천하기
  ? 검색 패턴 분석, 시간별로 보고 세션으로 나눔. 키워드가 같이 나올 확률
  - pairwise mutual information(PMI) : 중요! 중요! 중요!

 2. 실제 상품 구매 이동으로 많이 갈만한 관련 검색어를 추천하기 
  - 각 검색어별 상품 이동 수 등을 분석해야함
  - 구매로 넘어가는 비율과 1번과의 혼합

 3. 검색어 별로 구매하려고 가는 상품들의 가격을 regression 모델로 예측하기 
  - "에이컨" 이라고 검색했을때 검색 결과로 나오기에 적절 상품 가격대 예측 ,
   그래서 추후에 검색 랭킹을 개선할때 활용(적절하지 않은 가격대의 상품은  score 마이너스)
   이때 어떤 검색어를 입력해서 실제 해당 상품 상세 정보로 이동한 로그 정보를 활용
"""

# items.csv는 멘토님께서 주신 파일
data_table = DataFrame.from_csv('items.csv')

""" data_table attributes:
 1. id : 모두 다 다름, 현재 unique함
 2. name : 게시물 제목
 3. img : 이미지 url
 4. date
 5. site_name : 분야
 6. site_url 
 7. start_time  
 8. end_time 
 9. original_price
 10.crawling_id : ?
 11.parent_id : ?
 12.price
 13. auto_cate1 : auto categories (?), 수정
 14. img_list
 15. is_auto_cate 
"""
data_table
#data_table['name'][0] <- 0 번째 원소 꺼내기
# Out:
# /usr/local/lib/python2.7/site-packages/pandas/io/parsers.py:1139: DtypeWarning: Columns (0,1,4,10,11,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = self._reader.read(nrows)
#              id                                               name  \
# 0        697345                      덴비 그리니치 한식 국,밥,찬기 6인조 세트(20P)
# 1        695503                                 지나송 대형 웨딩커튼세트+쿠션커버
# 2        695501  풍년 베르투 압력솥세트 (압력솥 바디 2개 (3.5L, 4.5L)+압력솥 뚜껑+넘침방지
# 3        695499                     안국 고함량 루테인 10박스/10개월분+발포비타민 4병
# 4        695508                                        에바로렌 셔링부티샌들
# 5        695506                        락앤락 리빙박스 8개+다목적보관함+무료체험 일주일
# 6        958424  [(주)여행박사] [괌][2/11-2/28(일화)출발]아웃리거+괌 아일랜드관광+노쇼...
# 7        724000  예림당 와이 WHY? 역사+인문사회 64권 풀세트(역사42권+인문사회 22권)+아름...
# 8        695522           GS 단독 특가 1만원가격인하 RYN(여)키높이 쿨워킹화 그레이 3종세트
# 9        695545                               센스맘 에어매트리스II (퀸 사이즈)
# ...
